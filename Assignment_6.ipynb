# %% [markdown]
# **Name:** Mahendra Pratap Singh | **Reg ID:**  GO_STP_7372 | **Intern at:** Goeduhub Technologies | **Assignment:**6 | **Machine Learning**

# %% [markdown]
# #### 1. Load the necessary package for plotting using pyplot from matplotlib.
#
# Example: Days(x-axis) represents 8 days and Speed represents a car’s speed.Plot a
# Basic line plot between days and car speed, put x axis label as days and y axis
# label as car speed and put title Car Speed Measurement.

# %% [markdown]
# **Importing packages**

# %%
from pandas import*
import pandas as pd
from numpy import*
import numpy as np 
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
Days = [1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]

# %%
plt.plot(Days,Speed,linewidth = 4,color='royalblue')
plt.xlabel('Days',weight = 'bold')
plt.ylabel('Car Speed',weight = 'bold')
plt.title('Car Speed Measurement', fontweight="bold")
plt.show()

# %% [markdown]
# **2.** Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change marker size, markerface color etc.

# %%
plt.plot(Days,Speed, 'go--',marker='o', linewidth=2, markersize=12,color='royalblue')
plt.xlabel('Days',weight = 'bold')
plt.ylabel('Car Speed',weight = 'bold')
plt.title('Car Speed Measurement', fontweight="bold")
plt.grid()#to remove extralines

# %% [markdown]
# **3.** Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.

# %%
days = [1,2,3,4,5,6,7,8]
max_speed = [80,91,92,88,77,79,76,75]
min_speed = [42,43,40,42,33,36,34,35]
avg_speed = [46,58,57,56,40,42,41,36]
plt.plot(days,max_speed,label='max_speed',color="royalblue")
plt.plot(days,min_speed,label="min_speed",color="limegreen")
plt.plot(days,avg_speed,label="avg_speed",color="deeppink")
plt.legend()
plt.title('Car speed measurement',fontweight="bold")
plt.xlabel('Days',weight = 'bold')
plt.ylabel('Speed',weight = 'bold')
plt.show()

# %% [markdown]
# **4.** Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.

# %%
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
z=np.cos(x)
plt.plot(x,y,':b',label='sine',color="royalblue",linewidth=3)
plt.plot(x,z,'g--',label='cosine',color="limegreen",linewidth=3)
plt.xlabel('Angle',weight = 'bold')
plt.ylabel('Magnitude',weight = 'bold')
plt.title('Sine_cosine_curve',fontweight = 'bold')
plt.legend()
plt.show()

# %% [markdown]
# **5.** Plot Simple bar chart showing popularity of Programming Languages.Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
Languages = ['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

# %%
plt.bar(Languages,Popularity,color="violet",label='Popularity',width=.8)
plt.xlabel('Languages',weight='bold')
plt.ylabel('Popularity',weight='bold')
plt.title('Programming Languages Popularity',fontweight = 'bold')
plt.show()

# %%
ax = np.arange(len(Languages))

plt.bar(ax - 0.2, Popularity, 0.4, label = 'Popularity',color= "limegreen")
plt.bar(ax + 0.2, Security, 0.4, label = 'Security',color= "deeppink")

plt.xticks(ax, Languages)
plt.xlabel("Languages",weight='bold', size=10)
plt.ylabel("Popularity and Security Score", weight='bold', size=10)
plt.title("Popularity vs Security", weight='bold')
plt.legend()
plt.show()

# %%
plt.barh(ax + 0.2, Popularity, 0.5, label = 'Popularity',color="royalblue")
plt.barh(ax - 0.2, Security, 0.5, label = 'Security',color= "deeppink")

plt.yticks(X_axis, Languages)
plt.ylabel("Languages",weight='bold',size=10)
plt.xlabel("Popularity and Security Score", weight='bold', size=10)
plt.title("Popularity vs Security", weight='bold')
plt.legend()
plt.show()

# %% [markdown]
# **6.**  Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# Histogram showing Below Average, Average and Execellent distribution
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
marks =np.array([ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
belw_avg=marks[np.logical_and(marks >= 40,marks<60)]
avg=marks[np.logical_and(marks >= 60,marks<80)]
excel=marks[np.logical_and(marks >= 80,marks<100)]
plt.figure(figsize=(10,5))
plt.hist(marks, align='right', color='lime', edgecolor='black')
plt.xlabel('Bins', weight='bold')
plt.ylabel('Marks',weight='bold')
plt.title('Histogram of Marks',fontweight = 'bold')
plt.vlines([40, 60, 80,100], ymin=0, ymax=4, colors='k',linestyles='dashed')
plt.show()

# %% [markdown]
# **7.** Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
data = read_csv('titanic_original.csv')
data.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor    male   0.9167    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
mf=data['sex'].value_counts()
colors = ['lime', 'deeppink']
plt.figure(figsize=(5,5))
plt.pie(mf.values.tolist(),labels=mf.index.values.tolist(),colors=colors,startangle=90,autopct='%.1f%%',shadow = True)
plt.title('Male_Female proportion',fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Male_Female proportion')

# %%
male = data[data['sex'] == 'male']
print("Number of",male.sex.value_counts())

female = data[data['sex'] == 'female']
print("Number of",female.sex.value_counts())
# Out:
# Number of male    843
# Name: sex, dtype: int64
# Number of female    466
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.scatter(male.fare,male.age,label='Male',color='royalblue',marker='*')
plt.scatter(female.fare,female.age,label='Female',color='deeppink',marker='.')
plt.xlabel('Fare', weight='bold')
plt.ylabel('Age',weight='bold')
plt.title('Scatter Plot',fontweight = 'bold')
plt.legend()
plt.show()

# %% [markdown]
# **Done**
